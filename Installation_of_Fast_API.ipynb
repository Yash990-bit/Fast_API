# %% [markdown]
# # Fast API?
#
# FastAPI is a modern, high-performance Python web framework for building APIs. It is based on Python type hints and automatically generates interactive API documentation.
#
# # Installation
#
# pip install fastapi uvicorn

# %% [markdown]
# #Simple Example
#
# **Create a file main.py:**

# %%
from fastapi import FastAPI


app = FastAPI()

@app.get("/")
def read_root():
    return {"message": "Hello, FastAPI!"}

@app.get("/items/{item_id}")
def read_item(item_id: int):
    return {"item_id": item_id}

# Run the server:

# uvicorn main:app --reload

# %% [markdown]
# # Starlette (HTPPS request process)
#
# Starlette ek lightweight ASGI framework hai jo web application aur APIs banane ke liye use hota hai.
#
# # Layman Example
#
# Socho FastAPI ek car hai.
#
# Starlette = Engine
#
# Pydantic = Quality Checker
#
# FastAPI = Complete Car
#
# # Pydantic (data validation)
#
# Pydantic data validation aur serialization ke liye use hota hai.
#
# # Layman Example
#
# Maan lo user registration form fill karta hai:
#
# {
#     "name": "Yash",
#     "age": 21
# }
#
# Expected:
#
# name: str
#
# age: int

# %% [markdown]
# # FastAPI Request Flow
#
# User Request
#       ↓
#    Starlette
# (Route Handle)
#       ↓
#    Pydantic
# (Data Validation)
#       ↓
#  Business Logic
#       ↓
#  Response
#       ↓
#    Starlette
#       ↓
#     User

# %% [markdown]
# # One-Line Memory Trick
# Starlette → Request ko handle karta hai.
#
# Pydantic → Data ko validate karta hai.
#
# FastAPI → Dono ko combine karke API bana

# %% [markdown]
# # Why is FastAPI fast to run ?
#
# * ASGI use karta hai
#
# * Async/Await support
#    * async def get_users():
#
# * Starlette par built hai
#
# * Pydantic optimized validation
#
# * Uvicorn server
#
# # Layman Example
#
# Socho restaurant mein:
#
# Normal Framework
#
# Customer 1 → Serve
#
# Customer 2 → Wait
#
# Customer 3 → Wait
#
# FastAPI
#
# Customer 1 order diya
#
# Order kitchen mein gaya
#
# Tab tak Customer 2 aur 3 ke orders bhi le liye
#
# Isliye waiting time kam hota hai aur throughput zyada hota hai.

# %% [markdown]
# # FastAPI is fast because it uses ASGI, supports asynchronous programming with async/await, is built on the high-performance Starlette framework, uses optimized Pydantic validation, and typically runs on the Uvicorn ASGI server.

# %% [markdown]
# # Flask and Fast API
#
# ![WhatsApp Image 2026-06-08 at 15.28.09.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# # Why FastAPI is Faster
#
# * Uses ASGI instead of WSGI.
# * Supports async/await.
# * Built on Starlette (high-performance framework).
# * Uses optimized Pydantic validation.
# * Runs on fast ASGI servers like Uvicorn.

# %% [markdown]
# # Why is FastAPI fast to code?
#
# 1. Less Boilerplate Code
# 2. Automatic Data Validation
# 3. Auto API Documentation
# 4. Type Hints
# 5. Less Debugging

# %% [markdown]
# # FastAPI is fast to code because it provides automatic data validation through Pydantic, automatic API documentation, type-hint-based development, and requires very little boilerplate code. This reduces development time and helps developers build APIs quickly with fewer bugs.

# %% [markdown]
# # Code

# %%
from fastapi import FastAPI

# %%
app = FastAPI()

# %%
@app.get("/")
def hello():
    return {"message": "Hello World"}

    # To run in terminal we run command
    # * uvicorn main:app --reload

    # where app = FastAPI
    # and main is file name

# %%
@app.get('/about')
def about():
  return {"data":'send_message'}

# %% [markdown]
# # GET - kisi server se data fetch kar ke dekhna
#
# # POST - server ko data bhejna chahte ho
